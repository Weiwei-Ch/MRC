# %% [markdown]
# <a href="https://colab.research.google.com/github/Weiwei-Ch/MRC/blob/main/ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
#! ls "/content/drive/My Drive"
import os 
os.getcwd()
os.chdir('/content/drive/My Drive/Colab Notebooks/baidu_code/')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/baidu_code

# %%
# !ls
# Out:
# chinese_roberta_wwm_ext_pytorch.zip   main.py
# chinese_wwm_ext_pytorch.zip	      model
# data				      output
# ensemble.ipynb			      predict.sh
# ensemble.py			      process.py
# ensemble_results		      __pycache__
# ensemble.sh			      run_dureader_albert.sh
# eval_albert.sh			      run_dureader_bert.sh
# eval_ckp_bert.sh		      run_dureader_ernie.sh
# eval_ckp_roberta_large2.sh	      run_dureader_roberta_large_brightmart.sh
# eval_ckp_roberta_large_brightmart.sh  run_dureader_roberta_large.sh
# eval_ckp_roberta_large.sh	      run_dureader_roberta.sh
# eval_ckp_roberta.sh		      run_language_modeling.py
# eval_ensemble_model.sh		      run_language_modeling.sh
# evaluate.py			      runs
# __MACOSX			      transformers

# %%
# !pip install boto3
# Out:
# ...
#      |████████████████████████████████| 133kB 13.4MB/s
# ...
#      |████████████████████████████████| 71kB 8.5MB/s
# ...
#      |████████████████████████████████| 7.2MB 26.0MB/s
# ...
#      |████████████████████████████████| 143kB 56.9MB/s
# ...
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.2 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
# !pip install tokenizers
# Out:
# ...
#      |████████████████████████████████| 2.9MB 13.0MB/s
# ...

# %%
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.1MB 12.4MB/s
# ...

# %%
# !pip install sacremoses
# Out:
# ...
#      |████████████████████████████████| 890kB 13.0MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=4d23887d84b124cab57e57a611e8851245fabf1fd440694b3c2895f6573c882c
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# !pip install

# %%
# !bash run_dureader_bert.sh #roberta
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-27 15:37:38.863039: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-27:15:37:41,414 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-27:15:37:41,652 INFO     [configuration_utils.py:307] loading configuration file ./model/chinese_roberta_wwm_ext_pytorch/config.json
# 2020-12-27:15:37:41,653 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": null,
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
# ...

# %%
# !bash run_dureader_bert.sh  #wwm_ext
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-27 14:08:13.737889: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-27:14:08:42,270 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-27:14:08:42,274 INFO     [configuration_utils.py:307] loading configuration file ./model/chinese_wwm_ext_pytorch/config.json
# 2020-12-27:14:08:42,274 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": null,
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
# ...

# %%
# !bash run_dureader_bert.sh #wwm
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-27 16:53:57.464351: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-27:16:54:01,270 WARNING  [main.py:1031] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-27:16:54:01,511 INFO     [configuration_utils.py:307] loading configuration file ./model/chinese_wwm_pytorch/config.json
# 2020-12-27:16:54:01,512 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": null,
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
# ...

# %%
# !bash ensemble.sh   #w = [0.4,0.2,0.4] 集成模型
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-29 09:23:13.748159: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-29:09:23:15,836 WARNING  [ensemble.py:592] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-29:09:23:15,839 INFO     [configuration_utils.py:307] loading configuration file output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-29:09:23:15,839 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
# ...

# %%
# !bash ensemble.sh   #w = [1.0,0.0,0.0] robert
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-29 10:40:48.283373: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-29:10:40:50,351 WARNING  [ensemble.py:592] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-29:10:40:50,354 INFO     [configuration_utils.py:307] loading configuration file output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-29:10:40:50,354 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
# ...

# %%
# !bash ensemble.sh   #w = [0.0,1.0,0.0] wwm_ext
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-29 10:46:06.237972: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-29:10:46:08,298 WARNING  [ensemble.py:592] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-29:10:46:08,301 INFO     [configuration_utils.py:307] loading configuration file output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-29:10:46:08,301 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
# ...

# %%
# !bash ensemble.sh   #w = [0.0,0.0,1.0]  #wwm
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# 2020-12-29 10:49:58.121965: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-29:10:50:00,142 WARNING  [ensemble.py:592] Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 2020-12-29:10:50:00,144 INFO     [configuration_utils.py:307] loading configuration file output/chinese_roberta_wwm_ext_pytorch/DuReader/checkpoint-2000/config.json
# 2020-12-29:10:50:00,144 INFO     [configuration_utils.py:351] Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "directionality": "bidi",
#   "do_sample": false,
# ...
